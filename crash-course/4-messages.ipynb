# %% [markdown]
# ### Messages
#
# Important object definitions for messages and fundamental unit if context for models in Langchain. They contain role, content and metadata. "role" defines the type(AIMessage, ToolMessage)

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")
model = init_chat_model("groq:llama-3.3-70b-versatile")

# %% [markdown]
# ##### Text Prompts vs Message Prompts
#
# Text prompts are generally just strings; they ae used for straigtforward generation when retaining convo history is not priority.
#
# Message prompts can be used in lenghty conversations as they handle convo history but they include a bit of code complexity. A list of messages passed as message objects is required.

# %%
# Text Prompt

model.invoke("Hello")
# Out:
# AIMessage(content='Hello. How can I assist you today?', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 36, 'total_tokens': 46, 'completion_time': 0.024641758, 'completion_tokens_details': None, 'prompt_time': 0.003722021, 'prompt_tokens_details': None, 'queue_time': 0.051437383, 'total_time': 0.028363779}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_ba38bbab80', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--01a00235-f3f3-7512-b21e-4da8d4da92da-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 36, 'output_tokens': 10, 'total_tokens': 46})

# %% [markdown]
# Message Types: System Message, Human Message, AI Message, Tool Message

# %%
from langchain.messages import SystemMessage, HumanMessage, AIMessage

messages=[
    SystemMessage("You are a world-renounded poetry writer, flawless writer."),
    HumanMessage(content="wRITE A POEM ABOUT PARROTIC CARROTS", name="Harry de Souza", id="agent47")
]

response = model.invoke(messages)
response.content
# Out:
# "In vibrant hues, they danced with glee,\nThe parrotic carrots, a sight to see,\nTheir orange, yellow, and green feathers bright,\nInviting all to partake in their delightful sight.\n\nTheir leafy tops, a crown of emerald sheen,\nSwayed gently in the breeze, like a lover's scene,\nTheir slender bodies, a testament to nature's art,\nA symphony of color, that reached the heart.\n\nIn gardens they grew, where sunbeams played,\nDrinking in the light, their beauty unafraid,\nTheir sweetness and crunch, a treasure to share,\nA snack for the senses, beyond compare.\n\nOh, parrotic carrots, how you delight,\nWith your whimsical charm, and your wondrous sight,\nYou add a splash of color, to the mundane ground,\nA ray of sunshine, that spreads joy all around.\n\nIn stews and in salads, you add your zest,\nA burst of flavor, that's simply the best,\nYour parrotic charm, a treasure to behold,\nA gift from the earth, that never grows old.\n\nSo here's to the parrotic carrots, a tribute to their might,\nA celebration of their beauty, in the warm sunlight,\nMay their vibrant colors, and their sweetness never fade,\nFor they are a treasure, that's forever displayed."

# %%
from langchain.messages import ToolMessage

ai_msg = AIMessage(
    content=[],
    tool_calls=[{
        "name": "get_weather",
        "args": {"location": "San Francisco"},
        "id": "call_123"
    }]
)

weather_result = "Sunny, 72F"
tool_msg = ToolMessage(
    content=weather_result,
    tool_call_id="call_123"
)

messages = [
    HumanMessage("What's the weather in San Francisco?"),
    ai_msg,
    tool_msg
]

response = model.invoke(messages)
messages.append(response)

print(response.content)
print(messages)
print(response.usage_metadata)
# Out:
# It's a beautiful day in San Francisco with plenty of sunshine and a temperature of 72°F (22°C).
# [HumanMessage(content="What's the weather in San Francisco?", additional_kwargs={}, response_metadata={}), AIMessage(content=[], additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_weather', 'args': {'location': 'San Francisco'}, 'id': 'call_123', 'type': 'tool_call'}], invalid_tool_calls=[]), ToolMessage(content='Sunny, 72F', tool_call_id='call_123'), AIMessage(content="It's a beautiful day in San Francisco with plenty of sunshine and a temperature of 72°F (22°C).", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 24, 'prompt_tokens': 74, 'total_tokens': 98, 'completion_time': 0.096681311, 'completion_tokens_details': None, 'prompt_time': 0.005987459, 'prompt_tokens_details': None, 'queue_time': 0.05255498, 'total_time': 0.10266877}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_f8b414701e', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--01a00248-6e82-71b0-883d-bf8d6af736a3-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 74, 'output_tokens': 24, 'total_tokens': 98})]
# {'input_tokens': 74, 'output_tokens': 24, 'total_tokens': 98}
